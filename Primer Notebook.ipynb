# %% [markdown]
# # Primer Notebook

# %% [markdown]
# ## Subtítulo 1

# %%
ubi_archivo = '/content/Clase 1 CE.xlsx'
'/content/drive/MyDrive/Computación estadística 2022-1'

# %% [markdown]
# ![python](https://t1.ev.ltmcdn.com/es/posts/1/2/8/caracteristicas_del_planeta_tierra_que_hacen_posible_la_vida_1821_orig.jpg)

# %% [markdown]
# * Link de la imagen (https://t1.ev.ltmcdn.com/es/posts/1/2/8/caracteristicas_del_planeta_tierra_que_hacen_posible_la_vida_1821_orig.jpg)

# %% [markdown]
# $$\begin{bmatrix}
# 1 & 0 & 4 & -6 \\
# 2 & 5 & 0 & 3 \\
# -1 & 2 & 3 & 5 \\
# 2 & 1 & -2 & 3 \\
# \end{bmatrix}$$

# %% [markdown]
# # **$$\binom{n}{x}p^{x}q^{n-x}$$**

# %% [markdown]
# $ \begin{array}{ccc}
# \text{Nombre}&\text{Apellido}&\text{Edad}\\
# Camila&Camargo&19
# \end{array} $
